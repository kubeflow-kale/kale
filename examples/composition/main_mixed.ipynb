# %% [markdown]
# # Mixed composition (Story 2)
#
# The same three referenced notebooks, plus this notebook's own `step:` cell.
# `step:` cells are ordinary Kale; what Story 2 adds is the mixing: a composition
# notebook may carry them alongside its `notebook:` references. Each such step
# becomes a top-level component and runs in reading order.

# %%
print("final prediction:", prediction)
